# %%
import pandas as pd

df = pd.read_csv('talking_percents_combined.csv')
# filter the "filename" rows that have a 1 in "part+eval" column
df = df[df['participant'] == "1"]
df
# Out:
#                                  filename participant  eval  part+eval  \
# 0           FONDECYT_BE00142_RutinaDiaria           1   NaN        NaN
# 1                FONDECYT_BE00143_Lectura           1   NaN        NaN
# 2                FONDECYT_BE00154_Lectura           1   NaN        NaN
# 3            FONDECYT_BE00184_Renarracion           1   NaN        NaN
# 4                FONDECYT_BE00189_Lamina2           1   NaN        NaN
# ..                                    ...         ...   ...        ...
# 268  CETRAM_AMG-0034_DescripcionDeDibujo2           1   0.0        0.0
# 270      CETRAM_AMG-0012_LecturaDeParrafo           1   0.0        0.0
# 272          FONDECYT_SL00320_Renarracion           1   0.0        0.0
# 273       Slachevsky_CTR_052_Desagradable           1   0.0        0.0
# 274          FONDECYT_SL00369_Renarracion           1   0.0        0.0
#
#      over_threshold
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ..              ...
# 268            True
# 270            True
# 272            True
# 273            True
# 274           False
#
# [166 rows x 5 columns]
